# %% [markdown]
# We have only ten minutes:
#
# We talk about 2 famous libraries: NumPy and Pandas
#
# We pay attention to Spaghetti Code, the Global Variables and to the smallest version of the code
#
# NumPy people says that "arrays" are superfast (more than lists)
#
# Array are superfast and we use the "loop", support vector arithmetics operations and the brodcasting

# %%
l=[1,2,3]

# %%
import numpy as np 
no_arr = np.arrange .....

# %%
# list comprehension => ......

# we did the numpy test and we see that the numpy array are absolutely the best (with respect to list or to the loop)
