# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parent
sys.path.append(str(ROOT))

from src.preprocessing_mbp1 import load_single_dbn

file_path = ROOT / "data/raw/databento/UL/mbp1/xnas-itch-20260310.mbp-1.dbn.zst"

df = load_single_dbn(file_path)

df.head()
# Out:
#                                                                ts_event  \
# ts_recv
# 2026-03-10 08:00:00.005634002+00:00 2026-03-10 08:00:00.005470503+00:00
# 2026-03-10 08:00:00.006255104+00:00 2026-03-10 08:00:00.006091869+00:00
# 2026-03-10 08:00:00.006548600+00:00 2026-03-10 08:00:00.006385666+00:00
# 2026-03-10 08:00:00.006673315+00:00 2026-03-10 08:00:00.006510271+00:00
# 2026-03-10 08:00:00.008856609+00:00 2026-03-10 08:00:00.008694025+00:00
#
#                                      rtype  publisher_id  instrument_id  \
# ts_recv
# 2026-03-10 08:00:00.005634002+00:00      1             2          16518
# 2026-03-10 08:00:00.006255104+00:00      1             2          16518
# 2026-03-10 08:00:00.006548600+00:00      1             2          16518
# 2026-03-10 08:00:00.006673315+00:00      1             2          16518
# 2026-03-10 08:00:00.008856609+00:00      1             2          16518
#
#                                     action side  depth  price  size  flags  \
# ...
